# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime as dt
from scipy.stats import linregress
from pprint import pprint

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)          

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 589

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
        
        # Run an API request for each of the cities
    try: 
        params = {"q":city, "units":"metric", "appid":weather_api_key}

        # Log the url, record, and set numbers
        print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
        
        # Add 1 to the record count
        record_count += 1

        # Parse the JSON and retrieve data
        api_response = requests.get(url, params)
            
        city_weather = api_response.json()        

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"] 
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | carnarvon
# Processing Record 2 of Set 1 | wailua homesteads
# Processing Record 3 of Set 1 | al mindak
# Processing Record 4 of Set 1 | mount gambier
# Processing Record 5 of Set 1 | ust-nera
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | grytviken
# Processing Record 8 of Set 1 | avarua
# Processing Record 9 of Set 1 | cedeira
# Processing Record 10 of Set 1 | georgetown
# Processing Record 11 of Set 1 | iqaluit
# Processing Record 12 of Set 1 | saldanha
# Processing Record 13 of Set 1 | vanino
# Processing Record 14 of Set 1 | tiksi
# Processing Record 15 of Set 1 | anadyr
# Processing Record 16 of Set 1 | west island
# Processing Record 17 of Set 1 | blackmans bay
# Processing Record 18 of Set 1 | langtoucun
# Processing Record 19 of Set 1 | gadzhiyevo
# Processing Record 20 of Set 1 | pikalevo
# Processing Record 21 of Set 1 | katima mulilo
# Processing Record 22 of Set 1 | hermanus
# Processing Record 23 of Set 1 | puerto natales
# Processing Record 24 of Set 1 | buka
# Processing Record 25 of Set 1 | bethel
# Processing Record 26 of Set 1 | barra de santo antonio
# Processing Record 27 of Set 1 | port-aux-francais
# Processing Record 28 of Set 1 | tanumah
# Processing Record 29 of Set 1 | aasiaat
# Processing Record 30 of Set 1 | touros
# Processing Record 31 of Set 1 | mar del plata
# Processing Record 32 of Set 1 | hithadhoo
# Processing Record 33 of Set 1 | olinda
# Processing Record 34 of Set 1 | whitehorse
# Processing Record 35 of Set 1 | marsabit
# Processing Record 36 of Set 1 | kapuskasing
# Processing Record 37 of Set 1 | barcelos
# Processing Record 38 of Set 1 | khandyga
# Processing Record 39 of Set 1 | palmer
# Processing Record 40 of Set 1 | dudinka
# Processing Record 41 of Set 1 | maceio
# Processing Record 42 of Set 1 | waitangi
# Processing Record 43 of Set 1 | kingsbridge
# Processing Record 44 of Set 1 | vadso
# Processing Record 45 of Set 1 | duong dong
# Processing Record 46 of Set 1 | chernyshevsk
# Processing Record 47 of Set 1 | zhangye
# Processing Record 48 of Set 1 | ilulissat
# Processing Record 49 of Set 1 | invercargill
# Processing Record 50 of Set 1 | east london
# Processing Record 0 of Set 2 | altamira
# Processing Record 1 of Set 2 | tabuk
# Processing Record 2 of Set 2 | puerto ayora
# Processing Record 3 of Set 2 | yellowknife
# Processing Record 4 of Set 2 | clodomira
# Processing Record 5 of Set 2 | voskresenskoye
# Processing Record 6 of Set 2 | atafu village
# Processing Record 7 of Set 2 | phalaborwa
# Processing Record 8 of Set 2 | margaret river
# Processing Record 9 of Set 2 | san antonio de pale
# Processing Record 10 of Set 2 | nemuro
# Processing Record 11 of Set 2 | lebu
# Processing Record 2 of Set 5 | la passe
# Processing Record 3 of Set 5 | ha'il
# Processing Record 4 of Set 5 | belyy yar
# City not found. Skipping...
# Processing Record 5 of Set 5 | yambio
# Processing Record 6 of Set 5 | sabang
# Processing Record 7 of Set 5 | minas de marcona
# Processing Record 8 of Set 5 | nhamunda
# Processing Record 9 of Set 5 | badger
# Processing Record 10 of Set 5 | kourou
# Processing Record 11 of Set 5 | polyarnyy
# Processing Record 12 of Set 5 | souillac
# Processing Record 13 of Set 5 | mwene-ditu
# Processing Record 14 of Set 5 | kenai
# Processing Record 15 of Set 5 | acapulco de juarez
# Processing Record 16 of Set 5 | slavyanka
# Processing Record 17 of Set 5 | udachny
# Processing Record 18 of Set 5 | hotan
# Processing Record 19 of Set 5 | miyako
# Processing Record 20 of Set 5 | hamilton
# Processing Record 21 of Set 5 | waajid
# Processing Record 22 of Set 5 | kirensk
# Processing Record 23 of Set 5 | rumbek
# Processing Record 24 of Set 5 | hayma'
# City not found. Skipping...
# Processing Record 25 of Set 5 | rio grande
# Processing Record 26 of Set 5 | kangding
# Processing Record 27 of Set 5 | kolyshley
# Processing Record 28 of Set 5 | bietigheim-bissingen
# Processing Record 29 of Set 5 | san patricio
# Processing Record 30 of Set 5 | sao joao da barra
# Processing Record 31 of Set 5 | bamboo flat
# Processing Record 32 of Set 5 | ippy
# Processing Record 33 of Set 5 | rabigh
# Processing Record 34 of Set 5 | mwinilunga
# Processing Record 35 of Set 5 | stanley
# Processing Record 36 of Set 5 | ijuw
# City not found. Skipping...
# Processing Record 37 of Set 5 | enewetak
# Processing Record 38 of Set 5 | vandenberg village
# Processing Record 39 of Set 5 | yung shue wan
# Processing Record 40 of Set 5 | brandon
# Processing Record 41 of Set 5 | eyl
# Processing Record 42 of Set 5 | kapa'a
# Processing Record 43 of Set 5 | yichang
# Processing Record 44 of Set 5 | nizhneangarsk
# Processing Record 45 of Set 5 | hoxtolgay
# City not found. Skipping...
# Processing Record 46 of Set 5 | creel
# Processing Record 47 of Set 5 | berezovyy
# Processing Record 48 of Set 5 | pokrovo-prigorodnoye
# Processing Record 49 of Set 5 | alice springs
# Processing Record 0 of Set 6 | tura
# Processing Record 1 of Set 6 | qaqortoq
# Processing Record 2 of Set 6 | lazaro cardenas
# Processing Record 3 of Set 6 | afaahiti
# Processing Record 4 of Set 6 | kruisfontein
# Processing Record 5 of Set 6 | la ronge
# Processing Record 6 of Set 6 | jawf al maqbabah
# Processing Record 7 of Set 6 | tikhvin
# Processing Record 8 of Set 6 | vernon
# Processing Record 9 of Set 6 | isangel
# Processing Record 10 of Set 6 | antsiranana
# Processing Record 11 of Set 6 | essaouira
# Processing Record 12 of Set 6 | anadarko
# Processing Record 13 of Set 6 | waingapu
# Processing Record 14 of Set 6 | tera
# Processing Record 15 of Set 6 | laguna
# Processing Record 16 of Set 6 | zouerate
# Processing Record 17 of Set 6 | chongwe
# Processing Record 18 of Set 6 | korla
# Processing Record 19 of Set 6 | skidaway island
# Processing Record 20 of Set 6 | harar
# Processing Record 21 of Set 6 | remire-montjoly
# Processing Record 22 of Set 6 | cockburn town
# Processing Record 23 of Set 6 | goldsboro
# Processing Record 24 of Set 6 | san andres
# Processing Record 25 of Set 6 | constantia
# Processing Record 26 of Set 6 | kambove
# Processing Record 27 of Set 6 | tynda
# Processing Record 28 of Set 6 | quellon
# Processing Record 29 of Set 6 | aykhal
# Processing Record 30 of Set 6 | fort bragg
# Processing Record 31 of Set 6 | mandalgovi
# Processing Record 32 of Set 6 | fisterra
# Processing Record 33 of Set 6 | sisimiut
# Processing Record 34 of Set 6 | kununurra
# Processing Record 35 of Set 6 | isabel
# Processing Record 36 of Set 6 | cuito
# Processing Record 37 of Set 6 | qarqin
# Processing Record 38 of Set 6 | port isabel
# Processing Record 39 of Set 6 | klyuchi
# Processing Record 40 of Set 6 | gunjur
# Processing Record 41 of Set 6 | kabansk
# Processing Record 42 of Set 6 | nova sintra
# Processing Record 43 of Set 6 | autlan de navarro
# Processing Record 44 of Set 6 | tralee
# Processing Record 45 of Set 6 | puerto baquerizo moreno
# Processing Record 46 of Set 6 | san pedro
# Processing Record 47 of Set 6 | st. john's
# Processing Record 48 of Set 6 | kasumkent
# Processing Record 49 of Set 6 | mirnyy
# Processing Record 0 of Set 7 | monduli
# Processing Record 1 of Set 7 | grand-bassam
# Processing Record 2 of Set 7 | jinzhou
# Processing Record 3 of Set 7 | tarabha
# Processing Record 4 of Set 7 | vorgashor
# Processing Record 5 of Set 7 | el jadid
# Processing Record 6 of Set 7 | nadym
# Processing Record 7 of Set 7 | uray
# Processing Record 8 of Set 7 | bansi
# Processing Record 9 of Set 7 | college
# Processing Record 10 of Set 7 | haiku-pauwela
# Processing Record 11 of Set 7 | taoudenni
# Processing Record 12 of Set 7 | choibalsan
# Processing Record 13 of Set 7 | bechar
# Processing Record 14 of Set 7 | belton
# Processing Record 15 of Set 7 | valparaiso
# Processing Record 16 of Set 7 | suozhen
# Processing Record 17 of Set 7 | pestovo
# Processing Record 18 of Set 7 | vila velha
# Processing Record 19 of Set 7 | monze
# Processing Record 20 of Set 7 | pacific grove
# Processing Record 21 of Set 7 | urangan
# Processing Record 22 of Set 7 | guerrero negro
# Processing Record 23 of Set 7 | el granada
# Processing Record 24 of Set 7 | balykchy
# Processing Record 25 of Set 7 | cannonvale
# Processing Record 26 of Set 7 | xiongzhou
# Processing Record 27 of Set 7 | vilyuchinsk
# Processing Record 28 of Set 7 | palapag
# Processing Record 29 of Set 7 | marshfield
# Processing Record 30 of Set 7 | freetown
# Processing Record 31 of Set 7 | inhambane
# Processing Record 32 of Set 7 | lycksele
# Processing Record 33 of Set 7 | sao gabriel da cachoeira
# Processing Record 34 of Set 7 | yinchuan
# Processing Record 35 of Set 7 | bontang
# Processing Record 36 of Set 7 | howrah
# Processing Record 5 of Set 9 | namtsy
# Processing Record 6 of Set 9 | sao jose da coroa grande
# Processing Record 7 of Set 9 | tidjikja
# Processing Record 8 of Set 9 | arraial do cabo
# Processing Record 9 of Set 9 | hakui
# Processing Record 10 of Set 9 | djambala
# Processing Record 11 of Set 9 | patong
# Processing Record 12 of Set 9 | bossier city
# Processing Record 13 of Set 9 | wenling
# Processing Record 14 of Set 9 | igarka
# Processing Record 15 of Set 9 | labuan
# Processing Record 16 of Set 9 | oranjemund
# Processing Record 17 of Set 9 | bikenibeu village
# Processing Record 18 of Set 9 | dhuusamarreeb
# Processing Record 19 of Set 9 | slantsy
# Processing Record 20 of Set 9 | mount pearl
# Processing Record 21 of Set 9 | ocean shores
# Processing Record 22 of Set 9 | port sudan
# Processing Record 23 of Set 9 | dakhla
# Processing Record 24 of Set 9 | caleta de carquin
# Processing Record 25 of Set 9 | fort-shevchenko
# Processing Record 26 of Set 9 | shingu
# Processing Record 27 of Set 9 | piracanjuba
# Processing Record 28 of Set 9 | novodvinsk
# Processing Record 29 of Set 9 | hirara
# Processing Record 30 of Set 9 | callao
# Processing Record 31 of Set 9 | mpika
# Processing Record 32 of Set 9 | wanxian
# Processing Record 33 of Set 9 | lillehammer
# Processing Record 34 of Set 9 | mhamid
# Processing Record 35 of Set 9 | tolanaro
# Processing Record 36 of Set 9 | tra mhor
# Processing Record 37 of Set 9 | laikit, laikit ii (dimembe)
# Processing Record 38 of Set 9 | marsh harbour
# Processing Record 39 of Set 9 | rocky mountain house
# Processing Record 40 of Set 9 | forest hills
# Processing Record 41 of Set 9 | tuy hoa
# Processing Record 42 of Set 9 | mahabe
# City not found. Skipping...
# Processing Record 43 of Set 9 | wattegama
# Processing Record 44 of Set 9 | rikaze
# Processing Record 45 of Set 9 | ixtapa
# Processing Record 46 of Set 9 | beyneu
# Processing Record 47 of Set 9 | carutapera
# Processing Record 48 of Set 9 | belo sur tsiribihina
# Processing Record 49 of Set 9 | aioun
# Processing Record 0 of Set 10 | brookings
# Processing Record 1 of Set 10 | talca
# Processing Record 2 of Set 10 | utrik
# Processing Record 3 of Set 10 | las heras
# Processing Record 4 of Set 10 | keren
# Processing Record 5 of Set 10 | thunder bay
# Processing Record 6 of Set 10 | yangjiang
# Processing Record 7 of Set 10 | keflavik
# Processing Record 8 of Set 10 | midvagur
# Processing Record 9 of Set 10 | dodge city
# Processing Record 10 of Set 10 | mehran
# Processing Record 11 of Set 10 | posto fiscal rolim de moura
# Processing Record 12 of Set 10 | leshan
# Processing Record 13 of Set 10 | al 'alamayn
# City not found. Skipping...
# Processing Record 14 of Set 10 | cidade velha
# Processing Record 15 of Set 10 | stratford
# Processing Record 16 of Set 10 | castillos
# Processing Record 17 of Set 10 | cruzeiro do sul
# Processing Record 18 of Set 10 | port glaud
# City not found. Skipping...
# Processing Record 19 of Set 10 | st ives
# Processing Record 20 of Set 10 | popondetta
# Processing Record 21 of Set 10 | haimen
# Processing Record 22 of Set 10 | leua
# Processing Record 23 of Set 10 | zaraza
# Processing Record 24 of Set 10 | nagqu
# Processing Record 25 of Set 10 | usuki
# Processing Record 26 of Set 10 | lerwick
# Processing Record 27 of Set 10 | saurimo
# Processing Record 28 of Set 10 | parsons
# Processing Record 29 of Set 10 | urbano santos
# Processing Record 30 of Set 10 | ta`u
# Processing Record 31 of Set 10 | porto novo
# Processing Record 32 of Set 10 | darwin
# Processing Record 33 of Set 10 | woolgoolga
# Processing Record 34 of Set 10 | port lincoln
# Processing Record 35 of Set 10 | tabas
# Processing Record 36 of Set 10 | ulladulla
# Processing Record 37 of Set 10 | jayapura
# Processing Record 38 of Set 10 | bandarbeyla
# Processing Record 39 of Set 10 | orchard mesa
# Processing Record 40 of Set 10 | usinsk
# Processing Record 41 of Set 10 | nong bua lamphu
# Processing Record 42 of Set 10 | dapa
# Processing Record 43 of Set 10 | summerside
# Processing Record 44 of Set 10 | flin flon
# Processing Record 45 of Set 10 | yarrawonga
# Processing Record 46 of Set 10 | pangai
# Processing Record 47 of Set 10 | tazacorte
# Processing Record 48 of Set 10 | chela
# Processing Record 49 of Set 10 | altai
# Processing Record 0 of Set 11 | northam
# Processing Record 1 of Set 11 | noosa heads
# Processing Record 2 of Set 11 | karayazi
# Processing Record 3 of Set 11 | solnechnyy
# Processing Record 4 of Set 11 | ilukste
# Processing Record 5 of Set 11 | sturgis
# Processing Record 6 of Set 11 | rakops
# Processing Record 7 of Set 11 | coquimbo
# Processing Record 8 of Set 11 | kidal
# Processing Record 9 of Set 11 | bayan nur
# City not found. Skipping...
# Processing Record 10 of Set 11 | embi
# Processing Record 11 of Set 11 | lib
# Processing Record 12 of Set 11 | chaiyaphum
# Processing Record 13 of Set 11 | hammerfest
# Processing Record 14 of Set 11 | thinadhoo
# Processing Record 15 of Set 11 | woodward
# Processing Record 16 of Set 11 | charters towers
# Processing Record 17 of Set 11 | yako
# Processing Record 18 of Set 11 | malango
# Processing Record 19 of Set 11 | kayyerkan
# Processing Record 20 of Set 11 | gamay
# Processing Record 21 of Set 11 | lillesand
# Processing Record 22 of Set 11 | kaya
# Processing Record 23 of Set 11 | jinghong
# Processing Record 24 of Set 11 | vingt cinq
# City not found. Skipping...
# Processing Record 25 of Set 11 | mangrol
# Processing Record 26 of Set 11 | arteche
# Processing Record 27 of Set 11 | tabou
# Processing Record 28 of Set 11 | aginskoye
# Processing Record 29 of Set 11 | borogontsy
# Processing Record 30 of Set 11 | port-vila
# Processing Record 31 of Set 11 | kailua-kona
# Processing Record 32 of Set 11 | padre bernardo
# Processing Record 33 of Set 11 | sehore
# Processing Record 34 of Set 11 | celestun
# Processing Record 35 of Set 11 | tual
# Processing Record 36 of Set 11 | zaragoza
# Processing Record 37 of Set 11 | walvis bay
# Processing Record 38 of Set 11 | nadvoitsy
# Processing Record 39 of Set 11 | masterton
# Processing Record 40 of Set 11 | lautoka
# Processing Record 41 of Set 11 | hilvan
# Processing Record 42 of Set 11 | oasis
# Processing Record 43 of Set 11 | sur
# Processing Record 44 of Set 11 | pamandzi
# Processing Record 45 of Set 11 | zhelezinka
# Processing Record 46 of Set 11 | kalevala
# Processing Record 47 of Set 11 | ingenio la esperanza
# Processing Record 48 of Set 11 | bageshwar
# Processing Record 49 of Set 11 | bathurst
# Processing Record 0 of Set 12 | huai mek
# Processing Record 1 of Set 12 | marsa alam
# Processing Record 2 of Set 12 | sanluri
# Processing Record 3 of Set 12 | malanje
# Processing Record 4 of Set 12 | padang
# Processing Record 5 of Set 12 | cill airne
# Processing Record 6 of Set 12 | kayangel
# Processing Record 7 of Set 12 | bako
# Processing Record 8 of Set 12 | bu'aale
# Processing Record 9 of Set 12 | muzayri'
# City not found. Skipping...
# Processing Record 10 of Set 12 | tarapur
# Processing Record 11 of Set 12 | betong
# Processing Record 12 of Set 12 | kavieng
# Processing Record 13 of Set 12 | mejit
# Processing Record 14 of Set 12 | la'ie
# Processing Record 15 of Set 12 | ponta delgada
# Processing Record 16 of Set 12 | piti village
# Processing Record 17 of Set 12 | whistler
# Processing Record 18 of Set 12 | galle
# Processing Record 19 of Set 12 | opuwo
# Processing Record 20 of Set 12 | sinabang
# Processing Record 21 of Set 12 | ciudad lazaro cardenas
# Processing Record 22 of Set 12 | ialibu
# Processing Record 23 of Set 12 | am djarass
# City not found. Skipping...
# Processing Record 24 of Set 12 | port macquarie
# Processing Record 25 of Set 12 | lupane
# Processing Record 26 of Set 12 | nacozari de garcia
# Processing Record 27 of Set 12 | tevragh zeina
# City not found. Skipping...
# Processing Record 28 of Set 12 | kulia village
# City not found. Skipping...
# Processing Record 29 of Set 12 | minas de matahambre
# City not found. Skipping...
# Processing Record 30 of Set 12 | nova vicosa
# Processing Record 31 of Set 12 | tranovaho
# City not found. Skipping...
# Processing Record 32 of Set 12 | benghazi
# Processing Record 33 of Set 12 | nouadhibou
# Processing Record 34 of Set 12 | kalmunai
# Processing Record 35 of Set 12 | el calafate
# Processing Record 36 of Set 12 | mjolby
# Processing Record 37 of Set 12 | quezon
# Processing Record 38 of Set 12 | queenstown
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data, columns = ['City','Lat','Lng', "Max Temp", "Humidity",
                                                  "Cloudiness", "Wind Speed", "Country", "Date"]) 

# Show Record Count
city_data_df.count()
# Out:
# City          563
# Lat           563
# Lng           563
# Max Temp      563
# Humidity      563
# Cloudiness    563
# Wind Speed    563
# Country       563
# Date          563
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          carnarvon -24.8667  113.6333     13.50        69           0
# 1  wailua homesteads  22.0669 -159.3780     29.44        72          40
# 2          al mindak  20.1588   41.2834     24.78        28           6
# 3      mount gambier -37.8333  140.7667      9.39        82          76
# 4           ust-nera  64.5667  143.2000     22.13        41          86
#
#    Wind Speed Country        Date
# 0        6.10      AU  1688776099
# 1        7.72      US  1688776100
# 2        1.38      SA  1688776100
# 3        8.82      AU  1688776100
# 4        3.13      RU  1688776100

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                carnarvon -24.8667  113.6333     13.50        69           0
# 1        wailua homesteads  22.0669 -159.3780     29.44        72          40
# 2                al mindak  20.1588   41.2834     24.78        28           6
# 3            mount gambier -37.8333  140.7667      9.39        82          76
# 4                 ust-nera  64.5667  143.2000     22.13        41          86
#
#          Wind Speed Country        Date
# City_ID
# 0              6.10      AU  1688776099
# 1              7.72      US  1688776100
# 2              1.38      SA  1688776100
# 3              8.82      AU  1688776100
# 4              3.13      RU  1688776100

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker="o",s=20,alpha=.75, edgecolors="k")

# Incorporate the other graph properties
date = dt.date.today().strftime("%d-%m-%Y")
plt.title(f"City Max Latitude vs. Temperature ({date})")
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker="o", s=20,alpha=.75, edgecolors="k")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity ({date})")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker="o", s=20,alpha=.75, edgecolors="k")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness ({date})")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker="o", s=20,alpha=.75, edgecolors="k")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed ({date})")
plt.ylabel("Wind Speed (ms)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def makeLinRegression(df, x_Col, y_Col):
        (regr_slope, regr_intercept, regr_r_val, _, _) = linregress(df[x_Col], df[y_Col])
        regr_line_x = np.array([a for a in range(int(min(df[x_Col].values)), int(max(df[x_Col].values)+1))])
        regr_line_y = regr_slope * regr_line_x + regr_intercept
    
        df_axes = df.plot(kind="scatter", x=x_Col, y=y_Col)
    
        df_axes.plot(regr_line_x, regr_line_y, 'r')
        return df_axes

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]
northern_cities_count = len(northern_hemi_df)

# Display sample data
northern_hemi_df
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        wailua homesteads  22.0669 -159.3780     29.44        72          40
# 2                al mindak  20.1588   41.2834     24.78        28           6
# 4                 ust-nera  64.5667  143.2000     22.13        41          86
# 8                  cedeira  43.6797   -8.0209     18.54        85          96
# 9               georgetown   5.4112  100.3354     26.97        85          20
# ...                    ...      ...       ...       ...       ...         ...
# 556               benghazi  32.1167   20.0667     25.57        78           0
# 557             nouadhibou  20.9310  -17.0347     23.99        69          10
# 558               kalmunai   7.4167   81.8167     26.56        78          89
# 560                 mjolby  58.3260   15.1237     13.84        92          43
# 561                 quezon   7.7303  125.0989     28.63        70          48
#
#          Wind Speed Country        Date
# City_ID
# 1              7.72      US  1688776100
# 2              1.38      SA  1688776100
# 4              3.13      RU  1688776100
# 8              7.33      ES  1688776101
# 9              2.57      MY  1688776102
# ...             ...     ...         ...
# 556            6.50      LY  1688776216
# 557            8.75      MR  1688776490
# 558            0.92      LK  1688776503
# 560            2.87      SE  1688776301
# 561            0.37      PH  1688776302
#
# [388 rows x 9 columns]

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] <= 0]
southern_cities_count = len(southern_hemi_df)

# Display sample data
southern_hemi_df
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             carnarvon -24.8667  113.6333     13.50        69           0
# 3         mount gambier -37.8333  140.7667      9.39        82          76
# 5               ushuaia -54.8000  -68.3000      1.81        64          40
# 6             grytviken -54.2811  -36.5092     -7.38        82          19
# 7                avarua -21.2078 -159.7750     25.03        88         100
# ...                 ...      ...       ...       ...       ...         ...
# 552      port macquarie -31.4333  152.9167     17.72        44           0
# 553              lupane -18.9315   27.8070      9.14        70           1
# 555         nova vicosa -17.8919  -39.3719     21.41        77          89
# 559         el calafate -50.3408  -72.2768     -4.10        72           3
# 562          queenstown -31.8976   26.8753     15.79        28         100
#
#          Wind Speed Country        Date
# City_ID
# 0              6.10      AU  1688776099
# 3              8.82      AU  1688776100
# 5             10.29      AR  1688776101
# 6              5.55      GS  1688776000
# 7              3.09      CK  1688776101
# ...             ...     ...         ...
# 552            3.34      AU  1688776500
# 553            1.80      ZW  1688776298
# 555            3.96      BR  1688776300
# 559            0.86      AR  1688776503
# 562            9.62      ZA  1688776504
#
# [175 rows x 9 columns]

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
n_temp_slope, n_temp_intercept, n_temp_r_val, _, _ = linregress(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"])

# Create x and y values for the regression line
regr_line_x = np.array([a for a in range(80)])
regr_line_y = n_temp_slope * regr_line_x + n_temp_intercept

# Scatter plot of Latitude vs. Max Temp
n_temp_axes = northern_hemi_df.plot(kind="scatter", x="Lat", y="Max Temp")
print(n_temp_axes)

# Plot the regression line
n_temp_axes.plot(regr_line_x, regr_line_y, "r")

# Add line equation annotation
line_eq = "y = " + str(round(n_temp_slope,2)) + "x + " + str(round(n_temp_intercept,2))
plt.annotate(line_eq, xy=(0.05, 0.05), xycoords='axes fraction', ha='left', va='bottom', fontsize=15, color="red")

# Set labels for x-axis and y-axis
plt.xlabel("Latitude")
plt.ylabel("Max Temp")

# Show the plot
plt.show()
print(f"The r-value is: {n_temp_r_val}")
# Out:
# Axes(0.125,0.11;0.775x0.77)
# The r-value is: -0.6320231621171818

# %%
# Linear regression on Southern Hemisphere
s_temp_slope, s_temp_intercept, s_temp_r_val, _, _ = linregress(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"])
s_temp_lat_axes = makeLinRegression(southern_hemi_df, "Lat", "Max Temp")

# Create x and y values for the regression line
regr_line_x = np.array([a for a in range(80)])
regr_line_y = s_temp_slope * regr_line_x + s_temp_intercept

# Add line equation annotation
line_eq = "y = " + str(round(s_temp_slope,2)) + "x + " + str(round(s_temp_intercept,2))
plt.annotate(line_eq, xy=(0.05, 0.05), xycoords='axes fraction', ha='left', va='bottom', fontsize=15, color="red")

# Set labels for x-axis and y-axis
plt.xlabel("Latitude")
plt.ylabel("Max Temp")

# Show the plot
plt.show()
print(f"The r-value is: {s_temp_r_val}")
# Out:
# The r-value is: 0.7471753995842974

# %% [markdown]
# The Max Temperature vs. Latitude plot for cities in the northern hemisphere is shown above for the max temperature appears to show a strong negative linear relationship with Latitude, however in the southern hemisphere the max temperature appears to show a strong positive linear relationship with Latitude.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
n_hum_slope, n_hum_intercept, n_hum_r_val, _, _ = linregress(northern_hemi_df["Lat"], northern_hemi_df["Humidity"])
n_hum_lat_axes = makeLinRegression(northern_hemi_df, "Lat", "Humidity")

# Create x and y values for the regression line
regr_line_x = np.array([a for a in range(80)])
regr_line_y = n_hum_slope * regr_line_x + n_hum_intercept

# Add line equation annotation
line_eq = "y = " + str(round(n_hum_slope,2)) + "x + " + str(round(n_hum_intercept,2))
plt.annotate(line_eq, xy=(0.05, 0.05), xycoords='axes fraction', ha='left', va='bottom', fontsize=15, color="red")

# Set labels for x-axis and y-axis
plt.xlabel("Latitude")
plt.ylabel("Humidity")

# Show the plot
plt.show()
print(f"The r-value is: {n_hum_r_val}")
# Out:
# The r-value is: -0.029053449349802626

# %%
# Southern Hemisphere
s_hum_slope, s_hum_intercept, s_hum_r_val, _, _ = linregress(southern_hemi_df["Lat"], southern_hemi_df["Humidity"])
n_hum_lat_axes = makeLinRegression(southern_hemi_df, "Lat", "Humidity")

# Create x and y values for the regression line
regr_line_x = np.array([a for a in range(80)])
regr_line_y = s_hum_slope * regr_line_x + s_hum_intercept

# Add line equation annotation
line_eq = "y = " + str(round(s_hum_slope,2)) + "x + " + str(round(s_hum_intercept,2))
plt.annotate(line_eq, xy=(0.05, 0.05), xycoords='axes fraction', ha='left', va='bottom', fontsize=15, color="red")

# Set labels for x-axis and y-axis
plt.xlabel("Latitude")
plt.ylabel("Humidity")

# Show the plot
plt.show()
print(f"The r-value is: {s_hum_r_val}")
# Out:
# The r-value is: 0.056418141007076594

# %% [markdown]
# The Humidity vs. Latitude plot for cities in the northern & southern hemisphere shown above. The data seems to show no relationship between the humidity and latitude.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
n_cloud_slope, n_cloud_intercept, n_cloud_r_val, _, _ = linregress(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"])
n_cloud_lat_axes = makeLinRegression(northern_hemi_df, "Lat", "Cloudiness")

# Create x and y values for the regression line
regr_line_x = np.array([a for a in range(80)])
regr_line_y = n_cloud_slope * regr_line_x + n_cloud_intercept

# Add line equation annotation
line_eq = "y = " + str(round(n_cloud_slope,2)) + "x + " + str(round(n_cloud_intercept,2))
plt.annotate(line_eq, xy=(0.05, 0.05), xycoords='axes fraction', ha='left', va='bottom', fontsize=15, color="red")

# Set labels for x-axis and y-axis
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

# Show the plot
plt.show()
print(f"The r-value is: {n_cloud_r_val}")
# Out:
# The r-value is: 0.053834988237348974

# %%
# Southern Hemisphere
s_cloud_slope, s_cloud_intercept, s_cloud_r_val, _, _ = linregress(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"])
s_cloud_lat_axes = makeLinRegression(southern_hemi_df, "Lat", "Cloudiness")

# Create x and y values for the regression line
regr_line_x = np.array([a for a in range(80)])
regr_line_y = s_cloud_slope * regr_line_x + s_cloud_intercept

# Add line equation annotation
line_eq = "y = " + str(round(s_cloud_slope,2)) + "x + " + str(round(s_cloud_intercept,2))
plt.annotate(line_eq, xy=(0.95, 0.95), xycoords='axes fraction', ha='right', va='top', fontsize=15, color="red")

# Set labels for x-axis and y-axis
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

# Show the plot
plt.show()
print(f"The r-value is: {s_cloud_r_val}")
# Out:
# The r-value is: -0.039816805417659695

# %% [markdown]
# The Cloudiness vs. Latitude plot for cities in the northern and southern hemisphere shown above. The data seems to show no relationship between cloudiness and latitude.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
n_cloud_slope, n_cloud_intercept, n_cloud_r_val, _, _ = linregress(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"])
n_cloud_lat_axes = makeLinRegression(northern_hemi_df, "Lat", "Wind Speed")

# Create x and y values for the regression line
regr_line_x = np.array([a for a in range(80)])
regr_line_y = n_cloud_slope * regr_line_x + n_cloud_intercept

# Add line equation annotation
line_eq = "y = " + str(round(n_cloud_slope,2)) + "x + " + str(round(n_cloud_intercept,2))
plt.annotate(line_eq, xy=(0.95, 0.95), xycoords='axes fraction', ha='right', va='top', fontsize=15, color="red")

# Set labels for x-axis and y-axis
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

# Show the plot
plt.show()
print(f"The r-value is: {n_cloud_r_val}")
# Out:
# The r-value is: -0.0633807725922085

# %%
# Southern Hemisphere
s_cloud_slope, s_cloud_intercept, s_cloud_r_val, _, _ = linregress(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"])
s_cloud_lat_axes = makeLinRegression(southern_hemi_df, "Lat", "Wind Speed")

# Create x and y values for the regression line
regr_line_x = np.array([a for a in range(80)])
regr_line_y = s_cloud_slope * regr_line_x + s_cloud_intercept

# Add line equation annotation
line_eq = "y = " + str(round(s_cloud_slope,2)) + "x + " + str(round(s_cloud_intercept,2))
plt.annotate(line_eq, xy=(0.95, 0.95), xycoords='axes fraction', ha='right', va='top', fontsize=15, color="red")

# Set labels for x-axis and y-axis
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

# Show the plot
plt.show()
print(f"The r-value is: {s_cloud_r_val}")
# Out:
# The r-value is: -0.21299216601706303

# %% [markdown]
# The Wind Speed vs. Latitude plot for cities in the northen and southern hemisphere shown above. The data seems to show no relationship between wind speed and latitude.
